# %% [markdown]
# # Author
# [Koen Aerts](https://koenaerts.ca/) @ [Mobia Technology Innovations](https://mobia.io)
#
# [myOpenHealth](https://mobia.io/healthcare/)

# %% [markdown]
# # Intro
# This notebook plots some of the individual heartbeat records that were generated from the "02_import_mitdb_data" notebook.

# %% [markdown]
# # Initialize
# Import dependencies.

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Load Data
# Change file name to select different file. The file must be CSV and each row should contain exactly 188 values.

# %%
data = np.loadtxt('data_ecg/mitdb/210_MLII.csv', delimiter=',')
print(data.shape)
# Out:
# (2536, 188)

# %% [markdown]
# # Visualize
# Change values to navigate around the data. Different colors are used for Normal vs Abnormal heartbeats.

# %%
for beatid in [0,1,2,3,99,200,502,2428,2443]:
    times = np.arange(187, dtype = 'float') / 187
    beat = data[beatid][:-1]
    anno = data[beatid][-1]
    plt.figure(figsize=(20,5))
    if (anno == 0.0):
      plt.plot(times, beat, 'b')
    else:
      plt.plot(times, beat, 'r')
    plt.xlabel('Time [s]')
    plt.ylabel('beat ' + str(beatid) + " type " + str(anno))
    plt.show()

# %%
data = np.loadtxt('data_ecg/mitdb/210_MLII.csv', delimiter=',')
print(data.shape)  # Check the shape of your data

beatids = [0, 1, 2, 3, 99, 200, 502, 2428, 2443]  # Original list

for beatid in beatids:
    if beatid >= data.shape[0]:  # Check if beatid is within valid range
        print(f"beatid {beatid} is out of bounds, skipping.")
        continue

    times = np.arange(187, dtype='float') / 187
    beat = data[beatid][:-1]
    anno = data[beatid][-1]
    
    plt.figure(figsize=(20, 5))
    if anno == 0.0:
        plt.plot(times, beat, 'b')
    else:
        plt.plot(times, beat, 'r')
    plt.xlabel('Time [s]')
    plt.ylabel('beat ' + str(beatid) + " type " + str(anno))
    plt.show()
# Out:
# (2536, 188)
